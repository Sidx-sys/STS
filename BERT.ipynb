# %%
from sentence_transformers import SentenceTransformer
from sentence_transformers import SentenceTransformer, InputExample, losses
from torch.utils.data import DataLoader 
import numpy as np

# %%
model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
import pickle

with open('data/train_data.pkl', 'rb') as f:
    train_data = pickle.load(f)
x_train = train_data['x']
y_train = train_data['y']

with open('data/test_data.pkl', 'rb') as f:
    test_data = pickle.load(f)
x_test = test_data['x']
y_test = test_data['y']

# %%
x_train[0]
# Out:
# ['A woman who is taking off a pink boa is stopping her bicycle on a bridge built for pedestrians',
#  'A woman who is wearing a pink boa is riding a bicycle down a bridge built for pedestrians']

# %%
formatted_train_data = [InputExample(texts=tr, label=(ts / 5)) for tr, ts in zip(x_train, y_train)]

# %%
train_dataloader = DataLoader(formatted_train_data, shuffle=True, batch_size=32)
train_loss = losses.CosineSimilarityLoss(model)

# %%
model.fit(train_objectives=[(train_dataloader, train_loss)], epochs=1, warmup_steps=100)
# Out:
# /home2/sidharth.giri/miniconda3/envs/pytorch_dep/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...

# %%
def get_embeddings(sent_1, sent_2):
    embeddings1 = model.encode(sent_1, convert_to_tensor=True).cpu().numpy()
    embeddings2 = model.encode(sent_2, convert_to_tensor=True).cpu().numpy()

    return embeddings1, embeddings2

# %%
with open('data/test_data.pkl', 'rb') as f:
    test_data = pickle.load(f)
x_test = test_data['x']
y_test = test_data['y']

# %%
def cosine_similarity(vec_1, vec_2):
    return vec_1@vec_2.T/(np.linalg.norm(vec_1) * np.linalg.norm(vec_2))

# %%
preds = []
for x in x_test:
    vec_1, vec_2 = get_embeddings(x[0], x[1])
    preds.append(5 * cosine_similarity(vec_1, vec_2))
# Out:
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...

# %%
import scipy
pearson_score, _ = scipy.stats.pearsonr(preds, y_test)
pearson_score
# Out:
# 0.8778744607320759
